# %% [markdown]
# TFM Carlos Toro Peñas
# ============================
#
# ---
#
# Import dataset from 2dFGRS file
# -----------------------------------------------------

# %% [markdown]
# This file is dedicated to the import data from 2dFGRS survey. Under the hood an API of python code is running in each sentence.In partucular is important the dfGRSImporter.py file:

# %%
import sys
import os
base_folder = os.getenv('PROJECT_TFM')
sys.path.insert(1, base_folder+'\\python\\')
sys.path.insert(1, base_folder+'\\python\\project\\2dfgrs\\')
import execute
import project

# %% [markdown]
# First we import the dataset, convert it to a CSV readable-file

# %%
execute.import_files()
# Out:
# 1
# 10001
# 20001
# 30001
# 40001
# 50001
# 60001
# 70001
# 80001
# 90001
# 100001
# 110001
# 120001
# 130001
# 140001
# 150001
# 160001
# 170001
# 180001
# 190001
# 200001
# 210001
# 220001
# 230001
# 240001
# End

# %% [markdown]
# Then we add the groups to all elements

# %%
execute.import_groups()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 execute.import_groups()
#
# File C:\desarrollo\git\uoc\tfm\python\project\2dfgrs\execute.py:12, in import_groups()
#       8 def import_groups():
#       9     load_2dfgrs_group_galaxy3.execute()
# ---> 12 def import_groups_galaxy():
#      13     load_2dfgrs_group_galaxy3.execute()
#
# File C:\desarrollo\git\uoc\tfm\python\project\2dfgrs\load_2dfgrs_group_galaxy3.py:17, in execute()
#      15 destiny = '{}\\data\\2dfgrs/2dfgrs-valid.csv'.format(base_folder)
#      16 sdss_real = dFGRSImporter(destiny, destiny)
# ---> 17 sdss_real.transform_final_dss(galaxy, groups)
#
# File C:\desarrollo\git\uoc\tfm\python\project\2dfgrs\dFGRSImporter.py:79, in dFGRSImporter.transform_final_dss(self, galaxy_file, groups_file)
#      77 galaxy_df = pd.read_csv(galaxy_file)
# ...

# %% [markdown]
# Finally show the data loaded:

# %%
execute.import_groups_galaxy()
# Out:
# 1
# 10001
# 20001
# 30001
# 40001
# 50001
# 60001
# 70001
# 80001
# 90001
# 100001

# %%
import pandas as pd
file = base_folder+'\\data\\2dfgrs\\2dfgrs-valid.csv'
print(file)
data = pd.read_csv(file)
data
# Out:
# C:\desarrollo\git\uoc\tfm\data\2dfgrs\2dfgrs-valid.csv
#         GAL_ID          ra        dec         x         y         z  redshift  \
# 0            2    3.627292 -32.966861  0.099988  0.006339 -0.064981    0.1229
# 1            3    3.586292 -32.388000  0.085393  0.005352 -0.054273    0.1038
# 2            5    3.608000 -32.711528  0.084924  0.005355 -0.054652    0.1036
# 3            6    3.612542 -32.862444  0.106340  0.006714 -0.068832    0.1308
# 4            7    3.613417 -33.013278  0.089646  0.005661 -0.058362    0.1099
# ...        ...         ...        ...       ...       ...       ...       ...
# 104907  332683  218.192917  -2.104833 -0.043573 -0.034280 -0.002038    0.0562
# 104908  332688  218.184250  -2.088833 -0.043808 -0.034454 -0.002033    0.0565
# 104909  332689  218.172000  -2.404389 -0.091945 -0.072281 -0.004911    0.1204
# 104910  332691  218.189667  -2.685111 -0.031195 -0.024539 -0.001861    0.0401
# ...

# %% [markdown]
# This wrap up the import of 2dFGRS file.
