# %% [markdown]
# TFM Carlos Toro Peñas
# ============================
#
# ---
#
# Import dataset from SDSS-Real space datafiles
# -----------------------------------------------------

# %% [markdown]
# This file is dedicated to the import data from SDSS survey with real modification. Under the hood an API of python code is running in each sentence.In particular is important the SDSSImporter.py file:

# %%
import sys
import os
base_folder = os.getenv('PROJECT_TFM')
sys.path.insert(1, base_folder+'\\python\\')
sys.path.insert(1, base_folder+'\\python\\project\\sdss\\')
import execute
import project

# %% [markdown]
# First we import the dataset, convert it to a CSV readable-file

# %%
execute.import_files_real()
# Out:
# 1
# 10001
# 20001
# 30001
# 40001
# 50001
# 60001
# 70001
# 80001
# 90001
# 100001
# 110001
# 120001
# 130001
# 140001
# 150001
# 160001
# 170001
# 180001
# 190001
# 200001
# 210001
# 220001
# 230001
# 240001
# 250001
# 260001
# 270001
# 280001
# 290001
# 300001
# 310001
# 320001
# 330001
# 340001
# 350001
# 360001
# 370001
# 380001
# 390001
# End

# %% [markdown]
# Then we add the groups to all elements

# %%
execute.import_groups()
# Out:
# 1
# 10001
# 20001
# 30001
# 40001
# 50001
# 60001
# 70001
# 80001
# 90001
# 100001
# 110001
# 120001
# 130001
# 140001
# 150001
# 160001
# 170001
# 180001
# 190001
# 200001
# 210001
# 220001
# 230001
# 240001
# 250001
# 260001
# 270001
# 280001
# 290001
# 300001
# 310001
# 320001
# 330001
# 340001
# 350001
# 360001
# 370001
# 380001
# 390001
# 400001
# 410001
# 420001
# 430001
# 440001
# 450001
# 460001
# 470001
# 480001
# 490001
# 500001
# 510001
# 520001
# 530001
# 540001
# 550001
# 560001
# 570001
# 580001
# 590001
# 600001
# 610001
# 620001
# 630001
# End

# %% [markdown]
# Finally show the data loaded:

# %%
execute.import_groups_real_galaxy()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 execute.import_groups_real_galaxy()
#
# File C:\desarrollo\git\uoc\tfm\python\project\sdss\execute.py:21, in import_groups_real_galaxy()
#      20 def import_groups_real_galaxy():
# ---> 21     load_sdss_group_galaxy3.execute(1)
#
# File C:\desarrollo\git\uoc\tfm\python\project\sdss\load_sdss_group_galaxy3.py:18, in execute(real)
#      16     groups_file = '{}\\data\\sdss\\SDSS7_galaxy_group.csv'.format(base_folder)
#      17     destiny = '{}\\data\\sdss\\SDSS7-valid.csv'.format(base_folder)
# ---> 18 sdss_real = SDSSImporter(destiny, destiny, real_importer)
#      19 sdss_real.transform_final_dss(galaxy_file, groups_file)
#
# UnboundLocalError: cannot access local variable 'real_importer' where it is not associated with a value

# %%
import pandas as pd
file = base_folder+'\\data\\sdss\\SDSS7-valid.csv'
print(file)
data = pd.read_csv(file)
data
# Out:
# C:\desarrollo\git\uoc\tfm\data\sdss\SDSS7-valid.csv
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       2 file = base_folder+'\\data\\sdss\\SDSS7-valid.csv'
#       3 print(file)
# ----> 4 data = pd.read_csv(file)
#       5 data
#
# ...

# %% [markdown]
# This wrap up the import of 2dFGRS file.
